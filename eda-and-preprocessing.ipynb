# %% [markdown]
# # 1. EDA and Data Understanding

# %% [markdown]
# ### Import modules

# %%
# Import Libraries
import os
import cv2
import random
import hashlib
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
import json
import torch
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms

# %%
# Set seeds for reproducibility
def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)

# %%
# Set plot style
sns.set(style='whitegrid')

# %% [markdown]
# ### Explore dataset

# %% [markdown]
# Let's define the dataset path and explore the folder structure.

# %%
# Define dataset paths
DATASET_DIR = Path("datasets/Dataset")
TRAIN_DIR = DATASET_DIR / "train"
TEST_DIR = DATASET_DIR / "test"

# Explore dataset structure
train_classes = sorted([d.name for d in TRAIN_DIR.iterdir() if d.is_dir()])
test_classes = sorted([d.name for d in TEST_DIR.iterdir() if d.is_dir()])

print(f"Train classes: {len(train_classes)}")
print(f"Test classes: {len(test_classes)}")
print("Sample classes:", train_classes[:5])

extra_test_class = set(test_classes) - set(train_classes)
print("Class in test but not in train:", extra_test_class)
# Out:
# Train classes: 19
# Test classes: 20
# Sample classes: ['Acne and Rosacea Photos', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Atopic Dermatitis Photos', 'Cellulitis Impetigo and other Bacterial Infections', 'Eczema Photos']
# Class in test but not in train: {'Bullous Disease Photos'}

# %% [markdown]
# We've confirmed that the dataset has 19 training classes and 20 test classes and it is organized into subfolders, one per skin disease category. Our observation is that the test set has 1 more class than the training set.
#
# We found that the test set contains one additional class Bullous Disease Photos which is not present in the training set. This will lead to a cold start problem, as the model will not have learned to recognize this class. Unless training data for this class is added, we should exclude it from performance evaluation or explicitly note it as a limitation of the dataset.

# %%
# Classes to exclude 
EXCLUDED_CLASSES = {"Bullous Disease Photos"}

# %% [markdown]
# ### Count Images per Class (Train vs Test)

# %% [markdown]
# Let's count the number of .jpg images in each class folder for both train/ and test/ splits as this will help reveal the overall dataset size and the per-class distribution which we will use for class imbalance detection.

# %%
def count_images(folder, excluded_classes=None):
    if excluded_classes is None:
        excluded_classes = set()
    return {
        cls.name: len(list(cls.glob("*.jpg")))
        for cls in folder.iterdir()
        if cls.is_dir() and cls.name not in excluded_classes
    }

train_counts = count_images(TRAIN_DIR)
test_counts = count_images(TEST_DIR, excluded_classes=EXCLUDED_CLASSES)

# Combine into DataFrame
df_dist = pd.DataFrame({
    "Class": list(train_counts.keys()),
    "Train Count": list(train_counts.values()),
    "Test Count": [test_counts.get(cls, 0) for cls in train_counts.keys()]
})
df_dist["Total"] = df_dist["Train Count"] + df_dist["Test Count"]
df_dist = df_dist.sort_values("Total", ascending=False)

print(df_dist.head())
# Out:
#                                                 Class  Train Count  \
# 0                             Acne and Rosacea Photos          840
# 1   Actinic Keratosis Basal Cell Carcinoma and oth...          322
# 7        Light Diseases and Disorders of Pigmentation          299
# 18         Warts Molluscum and other Viral Infections          248
# 14  Tinea Ringworm Candidiasis and other Fungal In...          122
#
#     Test Count  Total
# 0          231   1071
# 1          120    442
# 7           30    329
# 18          51    299
# 14          42    164

# %% [markdown]
# We've observed that class "Acne and Rosacea Photos" has by far the most samples (840 in train, 231 in test). Other classes like “Tinea Ringworm” have significantly fewer images. This confirms a strong class imbalance.
#
# Models trained on imbalanced datasets tend to become biased toward overrepresented classes which will lead to poor generalization. In medical diagnosis tasks, this can have critical consequences.

# %% [markdown]
# ### Plot Distribution (Train vs Test)

# %% [markdown]
# Let's visualise the number of images per class in both the training and test sets for easy visualisations.

# %%
plt.figure(figsize=(14, 6))
df_melted = df_dist.melt(id_vars="Class", value_vars=["Train Count", "Test Count"])

sns.barplot(data=df_melted, x="value", y="Class", hue="variable", palette="Set2")
plt.title("Train/Test Image Count per Class", fontsize=16)
plt.xlabel("Number of Images")
plt.ylabel("Skin Disease Class")
plt.tight_layout()
plt.show()

# %% [markdown]
# The dataset follows a long-tail pattern, where a few classes dominate the total image count, and the majority of classes have very few examples which should be addressed.
#
# It contains 20 skin disease classes in both train and test folders. It is severely imbalanced as the class “Acne and Rosacea Photos” alone has over 800 training images, which far exceeds all others.
#
# On the opposite extreme, several classes such as “Urticaria Hives”, “Vasculitis Photos”, and “Exanthems and Drug Eruptions” have fewer than 50 images in total.
#
# Test sets are consistently smaller but some classes e.g., “Urticaria Hives” appear to have no test examples at all or a very small number which may hinder generalization performance tracking.

# %% [markdown]
# ### Image Dimension Analysis

# %% [markdown]
# Let's examine the width and height of all images in both train and test folders to ensures that preprocessing will not lead to loss of crucial visual features.

# %%
def collect_image_sizes(folder):
    sizes = []
    for class_dir in folder.iterdir():
        if class_dir.is_dir():
            for img_path in class_dir.glob("*.jpg"):
                try:
                    with Image.open(img_path) as img:
                        sizes.append(img.size)
                except:
                    continue
    return sizes

train_sizes = collect_image_sizes(TRAIN_DIR)
test_sizes = collect_image_sizes(TEST_DIR)
all_sizes = train_sizes + test_sizes

widths = [w for w, h in all_sizes]
heights = [h for w, h in all_sizes]

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
sns.histplot(widths, bins=30, color='skyblue')
plt.title("Image Width Distribution")
plt.xlabel("Width (pixels)")

plt.subplot(1, 2, 2)
sns.histplot(heights, bins=30, color='salmon')
plt.title("Image Height Distribution")
plt.xlabel("Height (pixels)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Most images are around 480–500 pixels wide, with a major peak at around 720 pixels. Most images fall between 480 and 750 pixels, with some outliers up to 1100 pixels tall. The majority of the dataset is reasonably consistent in size, but there are a few scattered outliers.

# %% [markdown]
# ### Sample Image Grid (One per Class)

# %% [markdown]
# Let's display one random image from each class in the training set to provide a quick visual sanity check and labeling allowing quick verification of image quality, class separation, source authenticity.

# %%
def plot_image_grid(data_dir, classes, images_per_class=1):
    plt.figure(figsize=(16, 10))
    class_dirs = list(data_dir.iterdir())

    shown = 0
    for class_index, class_folder in enumerate(class_dirs):
        if not class_folder.is_dir() or class_folder.name in EXCLUDED_CLASSES:
            continue
        image_files = list(class_folder.glob("*.jpg"))
        if not image_files:
            continue

        for i in range(images_per_class):
            if shown >= len(classes):
                break
            img_path = random.choice(image_files)
            try:
                img = Image.open(img_path)
            except:
                continue

            plt.subplot(4, 5, shown + 1)
            plt.imshow(img)
            plt.title(class_folder.name[:30], fontsize=9)
            plt.axis('off')

            shown += 1

    plt.suptitle("Sample Images from Each Class", fontsize=16)
    plt.tight_layout()
    plt.subplots_adjust(top=0.92)
    plt.show()

plot_image_grid(TRAIN_DIR, train_classes, images_per_class=1)

# %% [markdown]
# All images are readable, in good resolution, and not corrupted.The Dermnet watermark confirms the medical source is authentic. No blank, noisy, or mislabeled images were observed in this sample.
#
# Some classes are visually distinctive, such as Acne and Rosacea, Tinea Ringworm, and Vascular Tumors while others appear visually similar, e.g Seborrheic Keratoses, Psoriasis, and Lupus

# %% [markdown]
# ### Leaked images between train and test

# %% [markdown]
# Let's also ensure no test images are accidentally in training

# %%
def hash_image(image_path):
    try:
        with open(image_path, 'rb') as f:
            return hashlib.md5(f.read()).hexdigest()
    except:
        return None

def collect_image_hashes(dataset_path):
    hashes = set()
    for cls in dataset_path.iterdir():
        for img in cls.glob("*.jpg"):
            h = hash_image(img)
            if h:
                hashes.add(h)
    return hashes

train_hashes = collect_image_hashes(TRAIN_DIR)
test_hashes = collect_image_hashes(TEST_DIR)
leaks = train_hashes.intersection(test_hashes)
print(f"Leaked images between train and test: {len(leaks)}")
# Out:
# Leaked images between train and test: 209

# %% [markdown]
# There are 209 leaked images between the train and test datasets. This is a critical data quality issue which can significantly inflate the model’s test performance and hurt generalization. Let's resolve this

# %%
for cls_dir in TEST_DIR.iterdir():
    if not cls_dir.is_dir():
        continue
    for img_path in cls_dir.glob("*.jpg"):
        h = hash_image(img_path)
        if h in train_hashes:
            try:
                os.remove(img_path)
                print(f"Removed duplicate test image: {img_path}")
            except Exception as e:
                print(f"Failed to remove {img_path}: {e}")
# Out:
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07PerioralDermEye.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07Rhinophyma1.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07rhnophymas0321051.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07RosaceaFulFAce.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07RosaceaMilia0120.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07RosaceaOK0828063.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07sebDerem1101051.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07SteroidPerioral.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\07VascularFace0120.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\08PerioralDerm1.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-003.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-1.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-13.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-15.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-16.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-2.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-21.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-22.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-24.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-25.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-26.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-28.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-29.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-3.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-36.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-closed-comedo-4.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-114.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-120.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-122.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-126.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-128.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-131.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-133.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-135.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-137.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-141.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-148.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-149.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-19.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-3.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-30.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-40.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-44.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-45.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-61.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-85.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-86.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-89.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-cystic-90.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-excoriated-12.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-excoriated-14.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-excoriated-2.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-excoriated-22.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-excoriated-4.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-excoriated-8.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-infantile-12.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-infantile-6.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-1.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-13.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-14.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-15.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-17.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-18.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-24.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-26.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-37.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-48.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-57.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-58.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-61.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-62.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-63.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-67.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-69.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-open-comedo-72.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-13.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-15.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-17.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-20.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-21.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-26.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-34.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-37.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-38.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-41.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-51.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-59.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-61.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-66.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-67.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-7.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-pustular-8.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-scar-2.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\acne-scar-5.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\ComedonesEars-1.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-1.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-10.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-100.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-101.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-102.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-106.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-109.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-113.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-114.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-115.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-119.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-121.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-122.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-123.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-125.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-129.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-130.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-131.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-134.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-141.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-16.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-2.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-22.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-23.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-24.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-26.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-27.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-28.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-29.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-32.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-33.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-35.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-36.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-38.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-45.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-50.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-59.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-83.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-85.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-87.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-88.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-9.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-90.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-92.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\perioral-dermatitis-99.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rhinophyma-4.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-103.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-107.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-111.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-114.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-116.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-117.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-118.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-14.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-15.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-17.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-25.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-27.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-29.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-3.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-30.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-31.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-32.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-34.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-36.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-38.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-4.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-41.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-47.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-50.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-53.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-58.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-60.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-65.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-67.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-68.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-74.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-79.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-9.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-99.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-10.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-16.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-18.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-2.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-24.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-29.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-30.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-33.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-34.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-37.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-38.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-44.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-48.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-49.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-5.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-53.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-6.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-61.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-65.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-nose-7.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-steroid-1.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\rosacea-steroid-8.jpg
# Removed duplicate test image: datasets\Dataset\test\Acne and Rosacea Photos\sebaceous-glands-upper-lip-2.jpg
# Removed duplicate test image: datasets\Dataset\test\Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions\basal-cell-carcinoma-lip-28.jpg
# Removed duplicate test image: datasets\Dataset\test\Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions\squamous-cell-carcinoma-lip-3.jpg
# Removed duplicate test image: datasets\Dataset\test\Herpes HPV and other STDs Photos\molluscum-contagiosum-135.jpg
# Removed duplicate test image: datasets\Dataset\test\Light Diseases and Disorders of Pigmentation\milia-1.jpg
# Removed duplicate test image: datasets\Dataset\test\Light Diseases and Disorders of Pigmentation\milia-4.jpg
# Removed duplicate test image: datasets\Dataset\test\Lupus and other Connective Tissue diseases\lupus-chronic-cutaneous-40.jpg
# Removed duplicate test image: datasets\Dataset\test\Tinea Ringworm Candidiasis and other Fungal Infections\perleche-785.jpg
# Removed duplicate test image: datasets\Dataset\test\Tinea Ringworm Candidiasis and other Fungal Infections\tinea-face-48.jpg
# Removed duplicate test image: datasets\Dataset\test\Vascular Tumors\telangiectasias-6.jpg
# Removed duplicate test image: datasets\Dataset\test\Warts Molluscum and other Viral Infections\molluscum-contagiosum-113.jpg
# Removed duplicate test image: datasets\Dataset\test\Warts Molluscum and other Viral Infections\molluscum-contagiosum-98.jpg
# Removed duplicate test image: datasets\Dataset\test\Warts Molluscum and other Viral Infections\varicella-12.jpg

# %%
train_hashes = collect_image_hashes(TRAIN_DIR)
test_hashes = collect_image_hashes(TEST_DIR)
leaks = train_hashes.intersection(test_hashes)
print(f"Leaked images between train and test: {len(leaks)}")
# Out:
# Leaked images between train and test: 0

# %% [markdown]
# There are now zero leaked images. Let's create a test checksum to verify the version and ensure reproductibility

# %%
from hashlib import md5

def collect_image_hashes(directory):
    hashes = []
    for root, _, files in os.walk(directory):
        for f in sorted(files):
            if f.lower().endswith(('png', 'jpg', 'jpeg')):
                with open(os.path.join(root, f), 'rb') as img_file:
                    img_hash = md5(img_file.read()).hexdigest()
                    hashes.append(img_hash)
    return hashes

def dataset_checksum(directory):
    all_hashes = sorted(collect_image_hashes(directory))
    return md5(''.join(all_hashes).encode()).hexdigest()

print("Test set checksum:", dataset_checksum(TEST_DIR))
# Out:
# Test set checksum: bd28148d66132332ce7b7364e271fd26

# %% [markdown]
# This represents a unique fingerprint of the current test set image files.

# %%
def count_images(directory, excluded_classes=None):
    counts = {}
    for class_dir in os.listdir(directory):
        if excluded_classes and class_dir in excluded_classes:
            continue
        class_path = os.path.join(directory, class_dir)
        if os.path.isdir(class_path):
            counts[class_dir] = len([
                f for f in os.listdir(class_path) 
                if f.lower().endswith(('jpg', 'jpeg', 'png'))
            ])
    return counts

test_counts = count_images(TEST_DIR, excluded_classes=EXCLUDED_CLASSES)
print("Test counts after leak removal:", test_counts)
# Out:
# Test counts after leak removal: {'Acne and Rosacea Photos': 33, 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions': 118, 'Atopic Dermatitis Photos': 24, 'Cellulitis Impetigo and other Bacterial Infections': 14, 'Eczema Photos': 2, 'Exanthems and Drug Eruptions': 6, 'Herpes HPV and other STDs Photos': 5, 'Light Diseases and Disorders of Pigmentation': 28, 'Lupus and other Connective Tissue diseases': 24, 'Melanoma Skin Cancer Nevi and Moles': 5, 'Poison Ivy Photos and other Contact Dermatitis': 13, 'Psoriasis pictures Lichen Planus and related diseases': 24, 'Seborrheic Keratoses and other Benign Tumors': 31, 'Systemic Disease': 27, 'Tinea Ringworm Candidiasis and other Fungal Infections': 40, 'Urticaria Hives': 2, 'Vascular Tumors': 36, 'Vasculitis Photos': 1, 'Warts Molluscum and other Viral Infections': 48}

# %% [markdown]
# This output shows the number of test images remaining per class after removing any duplicates that were leaked from the training set. Some classes now have very few test samples such as 'Vasculitis Photos': 1,

# %% [markdown]
# # 2. Preprocessing Pipeline

# %% [markdown]
# From our EDA and Data Understanding, we have observed that there is need to prepare the images for modeling by resizing the images to ensure that they're all the same shape (preferrably 224×224), Normalizing and Augmenting to help model generalize.
#
# The input size of 224×224 is chosen as it's a standard for many pretrained models like ResNet, MobileNet among others allowing for easy transfer learning.
#
# We will use a well-structured PyTorch-compatible pipeline.

# %% [markdown]
# ### Define Transforms

# %% [markdown]
# The transformations below ensure that:
#
# 1. All images are resized to the same shape for batch processing
#
# 2. Training images receive random variations (augmentations) to improve generalization
#
# 3. Pixel intensities are normalized to match ImageNet pretrained model expectations.

# %%
# Define image size for consistency 
IMAGE_SIZE = 224

train_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=15),
    transforms.RandomResizedCrop(IMAGE_SIZE, scale=(0.8, 1.0)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ### Building a class

# %% [markdown]
# Let's build a class which ensures the dataset is compatible with PyTorch’s DataLoader, and allows us to apply resizing, augmentation, and normalization on the fly during training.

# %%
class SkinDiseaseDataset(Dataset):
    def __init__(self, root_dir, transform=None, exclude_classes=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self.class_to_idx = {}
        if exclude_classes is None:
            exclude_classes = set()

        for idx, class_name in enumerate(sorted(os.listdir(root_dir))):
            if class_name in exclude_classes:
                continue
            class_path = os.path.join(root_dir, class_name)
            if os.path.isdir(class_path):
                self.class_to_idx[class_name] = idx
                for fname in os.listdir(class_path):
                    if fname.endswith('.jpg'):
                        self.image_paths.append(os.path.join(class_path, fname))
                        self.labels.append(idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        label = self.labels[idx]
        try:
            image = Image.open(image_path)
            if image.mode != 'RGB':
                image = image.convert('RGB')
        except Exception as e:
            print(f"Error reading image {image_path}: {e}")
            return self.__getitem__((idx + 1) % len(self.image_paths))

        if self.transform:
            image = self.transform(image)
        return image, label

# %% [markdown]
# ### Dataset initialisation

# %%
train_dataset = SkinDiseaseDataset(TRAIN_DIR, transform=train_transforms)
test_dataset = SkinDiseaseDataset(TEST_DIR, transform=test_transforms, exclude_classes=EXCLUDED_CLASSES)

# %% [markdown]
# ### Class weights for imbalance

# %% [markdown]
# Let us also class weights for imbalance handling and to ensure fair learning across all disease categories.

# %%
label_counts = Counter(train_dataset.labels)
total = sum(label_counts.values())
class_weights = {cls: total / count for cls, count in label_counts.items()}
weights = [class_weights[label] for label in train_dataset.labels]
sampler = WeightedRandomSampler(weights, num_samples=len(weights), replacement=True)

plt.figure(figsize=(12, 4))
plt.bar(range(len(class_weights)), list(class_weights.values()))
plt.xlabel('Class ID')
plt.xticks(range(len(class_weights)), 
           [list(train_dataset.class_to_idx.keys())[i] for i in range(len(class_weights))],
           rotation=90)
plt.ylabel('Sampling Weight')
plt.title('Class Sampling Weights')
plt.show()

# %% [markdown]
# The plot confirms the sampler will aggressively oversample rare classes while dominant classes like "Acne and Rosacea" are appropriately downweighted.

# %% [markdown]
# ### Proof data augmentation pipeline works

# %% [markdown]
# To ensure our data augmentation pipeline is working as intended, we visualize a few randomly selected transformed training images.

# %%
def show_original_vs_augmented(dataset, n=3):
    fig, axes = plt.subplots(2, n, figsize=(15, 6))
    
    for i in range(n):
        # Get the original image path
        idx = random.randint(0, len(dataset) - 1)
        image_path = dataset.image_paths[idx]

        # Load original image using PIL
        original_image = Image.open(image_path).convert('RGB')
        axes[0, i].imshow(original_image)
        axes[0, i].set_title("Original")
        axes[0, i].axis('off')

        # Load augmented tensor
        augmented_tensor, _ = dataset[idx]
        # Unnormalize for visualization
        unnormalized = augmented_tensor.permute(1, 2, 0).numpy() * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406]
        unnormalized = np.clip(unnormalized, 0, 1)
        axes[1, i].imshow(unnormalized)
        axes[1, i].set_title("Augmented")
        axes[1, i].axis('off')

    plt.tight_layout()
    plt.show()

# Run the visualization
show_original_vs_augmented(train_dataset)

# %% [markdown]
# The bottom row shows transformations such as random rotation, flipping, resizing, and slight distortion (if added), while the top row shows the original images. This confirms that the augmentations are working correctly and introduce useful variability, which helps in improving the model's generalization.

# %% [markdown]
# ### DataLoader Setup

# %%
train_loader = DataLoader(train_dataset, batch_size=32, sampler=sampler, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %% [markdown]
# These will handle batching, shuffling, and parallel data loading.

# %% [markdown]
# ### Show class mapping

# %% [markdown]
# Let us show how class names have been mapped to numerical labels.

# %%
# Show class mapping
print(train_dataset.class_to_idx)

# Save mapping for inference
with open("class_to_idx.json", "w") as f:
    json.dump(train_dataset.class_to_idx, f)
# Out:
# {'Acne and Rosacea Photos': 0, 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions': 1, 'Atopic Dermatitis Photos': 2, 'Cellulitis Impetigo and other Bacterial Infections': 3, 'Eczema Photos': 4, 'Exanthems and Drug Eruptions': 5, 'Herpes HPV and other STDs Photos': 6, 'Light Diseases and Disorders of Pigmentation': 7, 'Lupus and other Connective Tissue diseases': 8, 'Melanoma Skin Cancer Nevi and Moles': 9, 'Poison Ivy Photos and other Contact Dermatitis': 10, 'Psoriasis pictures Lichen Planus and related diseases': 11, 'Seborrheic Keratoses and other Benign Tumors': 12, 'Systemic Disease': 13, 'Tinea Ringworm Candidiasis and other Fungal Infections': 14, 'Urticaria Hives': 15, 'Vascular Tumors': 16, 'Vasculitis Photos': 17, 'Warts Molluscum and other Viral Infections': 18}

# %% [markdown]
# The dataset contains 19 unique classes, each correctly mapped to a numerical index. This mapping will be used during training and prediction to associate model outputs with the corresponding skin disease class.
